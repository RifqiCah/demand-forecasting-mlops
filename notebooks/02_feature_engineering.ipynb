# %%
import pandas as pd

# %%
train_df = pd.read_csv('../data/raw/train.csv')

# %%
train_df['date'] = pd.to_datetime(train_df['date'])

# %% [markdown]
# STEP 3.1 — SORT DATA

# %%
train_df = train_df.sort_values(['store', 'item', 'date']).reset_index(drop=True)

# %% [markdown]
# STEP 3.2 — CALENDAR FEATURES

# %%
train_df['year'] = train_df['date'].dt.year
train_df['month'] = train_df['date'].dt.month
train_df['week'] = train_df['date'].dt.isocalendar().week.astype(int)
train_df['day'] = train_df['date'].dt.day
train_df['dayofweek'] = train_df['date'].dt.dayofweek

# %% [markdown]
# STEP 3.3 — LAG FEATURES

# %%
LAGS = [2, 14, 28]

for lag in LAGS:
    train_df[f'lag_{lag}'] = (
        train_df
        .groupby(['store', 'item'])['sales']
        .shift(lag)
    )

# %% [markdown]
# STEP 3.4 — ROLLING STATISTICS (SMOOTHING)

# %%
WINDOWS = [7, 14, 28]

for window in WINDOWS:
    train_df[f'rolling_mean_{window}'] = (
        train_df
        .groupby(['store', 'item'])['sales']
        .shift(1)
        .rolling(window)
        .mean()
    )

# %% [markdown]
# STEP 3.5 — HANDLE NaN

# %%
train_df.isna().sum()
# Out:
# date                   0
# store                  0
# item                   0
# sales                  0
# year                   0
# month                  0
# week                   0
# day                    0
# dayofweek              0
# lag_2               1000
# lag_14              7000
# lag_28             14000
# rolling_mean_7      3500
# rolling_mean_14     7000
# rolling_mean_28    14000
# dtype: int64

# %%
train_df_fe = train_df.dropna().reset_index(drop=True)

# %% [markdown]
# STEP 3.6 — QUICK SANITY CHECK

# %%
train_df_fe.shape
# Out:
# (899000, 15)

# %%
train_df_fe.head()
# Out:
#         date  store  item  sales  year  month  week  day  dayofweek  lag_2  \
# 0 2013-01-29      1     1      6  2013      1     5   29          1   12.0
# 1 2013-01-30      1     1      9  2013      1     5   30          2   11.0
# 2 2013-01-31      1     1     13  2013      1     5   31          3    6.0
# 3 2013-02-01      1     1     11  2013      2     5    1          4    9.0
# 4 2013-02-02      1     1     21  2013      2     5    2          5   13.0
#
#    lag_14  lag_28  rolling_mean_7  rolling_mean_14  rolling_mean_28
# 0     5.0    13.0       10.428571        10.642857        10.714286
# 1     7.0    11.0       10.285714        10.714286        10.464286
# 2    16.0    14.0       10.285714        10.857143        10.392857
# 3     7.0    13.0       11.000000        10.642857        10.357143
# 4    18.0    10.0       10.571429        10.928571        10.285714

# %% [markdown]
# ## Feature Engineering Summary
#
# - Calendar features were created to capture weekly and yearly seasonality.
# - Lag features (7, 14, 28 days) were generated to model temporal dependencies.
# - Rolling statistics were used to smooth short-term fluctuations.
# - All features were created using past data only to prevent data leakage.
